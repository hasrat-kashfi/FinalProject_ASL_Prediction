# %% [markdown]
# <a href="https://colab.research.google.com/github/hasrat-kashfi/FinalProject_ASL_Prediction/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 17.6 MB/s eta 0:00:00
# ...
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/val/X/X820.jpg
#   inflating: data/val/X/X821.jpg
#   inflating: data/val/X/X822.jpg
#   inflating: data/val/X/X823.jpg
#   inflating: data/val/X/X824.jpg
#   inflating: data/val/X/X825.jpg
#   inflating: data/val/X/X826.jpg
#   inflating: data/val/X/X827.jpg
#   inflating: data/val/X/X828.jpg
#   inflating: data/val/X/X829.jpg
#   inflating: data/val/X/X83.jpg
#   inflating: data/val/X/X830.jpg
#   inflating: data/val/X/X831.jpg
#   inflating: data/val/X/X832.jpg
#   inflating: data/val/X/X833.jpg
#   inflating: data/val/X/X834.jpg
#   inflating: data/val/X/X835.jpg
#   inflating: data/val/X/X836.jpg
#   inflating: data/val/X/X837.jpg
#   inflating: data/val/X/X838.jpg
#   inflating: data/val/X/X839.jpg
#   inflating: data/val/X/X84.jpg
#   inflating: data/val/X/X840.jpg
#   inflating: data/val/X/X841.jpg
#   inflating: data/val/X/X842.jpg
#   inflating: data/val/X/X843.jpg
#   inflating: data/val/X/X844.jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/yolo11x-cls.pt')

model.train(data='data', epochs=12)
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !zip -r data.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/classify/ (stored 0%)
#   adding: content/runs/classify/train/ (stored 0%)
#   adding: content/runs/classify/train/args.yaml (deflated 53%)
#   adding: content/runs/classify/train/weights/ (stored 0%)
#   adding: content/runs/classify/train2/ (stored 0%)
#   adding: content/runs/classify/train2/args.yaml (deflated 52%)
#   adding: content/runs/classify/train2/confusion_matrix.png (deflated 14%)
#   adding: content/runs/classify/train2/val_batch0_pred.jpg (deflated 5%)
#   adding: content/runs/classify/train2/train_batch2028.jpg (deflated 9%)
#   adding: content/runs/classify/train2/val_batch1_labels.jpg (deflated 5%)
#   adding: content/runs/classify/train2/val_batch2_labels.jpg (deflated 4%)
#   adding: content/runs/classify/train2/train_batch2.jpg (deflated 6%)
#   adding: content/runs/classify/train2/train_batch2027.jpg (deflated 10%)
#   adding: content/runs/classify/train2/train_batch1.jpg (deflated 8%)
# ...

# %%
from google.colab import files
files.download('data.zip')

# %%
from google.colab import files
files.download('/content/data/train.cache')
files.download('/content/data/val.cache')

# %%
model= YOLO('runs/classify/train2/weights/best.pt')
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLO11x-cls summary (fused): 227 layers, 28,367,003 parameters, 0 gradients, 110.4 GFLOPs
# train: /content/data/train... found 16200 images in 27 classes ✅
# val: /content/data/val... found 64800 images in 27 classes ✅
# test: None...
# val: Scanning /content/data/val... 64800 images, 0 corrupt: 100%|██████████| 64800/64800 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/data/val/A/A2.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/B/B2.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/C/C2.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/D/D2.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/E/E2.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/F/F2.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/data/val/G/G2.jpg: corrupt JPEG restored and saved
# ...

# %%
results=model('/content/k.jpg', save=True)
#results
for r in results:
    print(r.probs)
# Out:
# image 1/1 /content/k.jpg: 224x224 K 0.89, V 0.05, W 0.02, F 0.01, Z 0.01, 11.5ms
# Speed: 47.3ms preprocess, 11.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([4.3238e-04, 9.0053e-05, 2.4731e-04, 7.3335e-04, 4.5829e-05, 8.8932e-03, 3.6904e-03, 2.4742e-04, 3.1776e-04, 3.5830e-04, 8.9491e-01, 4.8379e-03, 1.7616e-03, 1.3071e-03, 6.7366e-04, 3.3870e-04, 1.3115e-03, 5.6628e-04, 4.1896e-05, 1.1764e-03, 1.3175e-04, 5.1038e-02, 1.8763e-02, 3.0489e-04, 4.9339e-04, 6.7444e-03,
#         5.4137e-04], device='cuda:0')
# orig_shape: None
# shape: torch.Size([27])
# top1: 10
# top1conf: tensor(0.8949, device='cuda:0')
# top5: [10, 21, 22, 5, 25]
# top5conf: tensor([0.8949, 0.0510, 0.0188, 0.0089, 0.0067], device='cuda:0')
